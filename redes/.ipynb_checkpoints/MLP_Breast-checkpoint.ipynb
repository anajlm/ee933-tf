# %%
from sklearn.neural_network import MLPClassifier
import matplotlib.pyplot as plt
import numpy as np
import csv 
import pandas as pd

percentualTreinamento = 0.7


dataset = {}
# Define the numeric labels to filter
labels={'M','B'}
labels_list = list(labels)


# Define column names based on dataset documentation
columns = [
    "ID", "Diagnosis",
    "Radius_mean", "Texture_mean", "Perimeter_mean", "Area_mean", "Smoothness_mean",
    "Compactness_mean", "Concavity_mean", "Concave_points_mean", "Symmetry_mean", "Fractal_dimension_mean",
    "Radius_se", "Texture_se", "Perimeter_se", "Area_se", "Smoothness_se",
    "Compactness_se", "Concavity_se", "Concave_points_se", "Symmetry_se", "Fractal_dimension_se",
    "Radius_worst", "Texture_worst", "Perimeter_worst", "Area_worst", "Smoothness_worst",
    "Compactness_worst", "Concavity_worst", "Concave_points_worst", "Symmetry_worst", "Fractal_dimension_worst"
]

# Load the dataset
df = pd.read_csv("../dataset/wdbc.data", names=columns, header=None)

# Drop the ID column (not useful for analysis)
df.drop(columns=["ID"], inplace=True)

# Filter rows where a column equals one of the labels
dadosBrutosLabel0 = dadosBrutos[dadosBrutos['label'] == labels_list[0]] 
dadosBrutosLabel1 = dadosBrutos[dadosBrutos['label'] == labels_list[1]] 

# metadata 
print(df.head())
print(df.shape)
# Out:
#   Diagnosis  Radius_mean  Texture_mean  Perimeter_mean  Area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    Smoothness_mean  Compactness_mean  Concavity_mean  Concave_points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    Symmetry_mean  ...  Radius_worst  Texture_worst  Perimeter_worst  \
# ...

# %%
# Total number of samples

nAmostras_treinamento = len(df)
tamanhoTreinamento = int(nAmostras_treinamento * percentualTreinamento)

    # Randomly select indices for group 1 - treinamento
    indices_label0_treinamento = np.random.choice(dadosBrutosLabel0.index, size=tamanho_label0, replace=False)
    # Select remaining indices for group 1 - teste
    indices_label0_teste = dadosBrutosLabel0.index.difference(indices_label0_treinamento)
    
    # Determine the size of group 2
    n_samples_1 = len(dadosBrutosLabel1)
    tamanho_label1 = int(n_samples_1 * percentualTreinamento)

    # Randomly select indices for group 2 - treinamento
    indices_label1_treinamento = np.random.choice(dadosBrutosLabel1.index, size=tamanho_label1, replace=False)
    # Select remaining indices for group 2 - teste
    label1_teste = dadosBrutosLabel0.index.difference(indices_label1_treinamento)

    trainData = dadosBrutosLabel0.loc[indices_label0_treinamento]
    buffer_trainData = dadosBrutosLabel1.loc[indices_label1_treinamento]
    testData = dadosBrutosLabel0.loc[indices_label0_teste]
    buffer_testData = dadosBrutosLabel1.loc[indices_label1_treinamento]
        
    filtered_rows_Train = pd.concat([trainData,buffer_trainData], axis=0)
    filtered_rows_Test = pd.concat([testData,buffer_testData], axis=0)
    
    trainData = filtered_rows_Train.iloc[:, 2:datasetColunaLabel].to_numpy()
    trainLabels= filtered_rows_Train.iloc[:, 59]
    testData = filtered_rows_Test.iloc[:, 2:datasetColunaLabel].to_numpy()
    testLabels= filtered_rows_Test.iloc[:, 59]
    
    #trainLabels[trainLabels==labels_list[0]] = 0
    #trainLabels[trainLabels==labels_list[1]] = 1
    trainLabels = trainLabels.replace({labels_list[0]: 0, labels_list[1]: 1})
    testLabels = testLabels.replace({labels_list[0]: 0, labels_list[1]: 1})

# %%
# Read the CSV file
trainData = pd.read_csv('../datasets/embeddings_test.csv')
testData = pd.read_csv('../datasets/embeddings_train.csv')

# Filter rows where a column equals one of the labels
filtered_rows_Train = trainData[trainData['label'].isin(labels)]  # Replace 'ColumnName' with your column name
filtered_rows_Test = testData[testData['label'].isin(labels)]  # Replace 'ColumnName' with your column name

trainData = filtered_rows_Train.iloc[:, :128].to_numpy()
trainLabels= filtered_rows_Train.iloc[:, 128].to_numpy()
testData = filtered_rows_Test.iloc[:, :128].to_numpy()
testLabels= filtered_rows_Test.iloc[:, 128].to_numpy()

# Ajusta os rótulos
trainLabels[trainLabels==labels_list[0]] = 0
trainLabels[trainLabels==labels_list[1]] = 1
testLabels[testLabels==labels_list[0]] = 0
testLabels[testLabels==labels_list[1]] = 1

# %%
# https://scikit-learn.org/stable/modules/neural_networks_supervised.html

clf = MLPClassifier(solver='lbfgs', alpha=1e-5,
                    hidden_layer_sizes=(128, 32))

clf.fit(trainData, trainLabels)
# Out:
# MLPClassifier(alpha=1e-05, hidden_layer_sizes=(5, 2), solver='lbfgs')

# %% [markdown]
# ## Conjunto de Treinamento

# %%
observados_treinamento=clf.predict(trainData)

MSE_treinamento = 1-(1/observados_treinamento.shape[0])*(np.power(np.sum(observados_treinamento-trainLabels),2))
print(MSE_treinamento*100)
# Out:
# 100.0

# %% [markdown]
# ## Conjunto de teste

# %%
observados=clf.predict(testData)

MSE_treinamento = np.sum(observados-testLabels)
MSE_treinamento = 1-(1/observados.shape[0])*np.power(MSE_treinamento,2)
MSE_teste*100
# Out:
# 99.99999350224422
